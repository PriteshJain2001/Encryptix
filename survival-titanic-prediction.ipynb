# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
test_data = pd.read_csv('/kaggle/input/survival-titanic-dataset/test.csv')
train_data=pd.read_csv('/kaggle/input/survival-titanic-dataset/train.csv')

# %%
train_data.head()

# %%
train_data.shape

# %%
train_data['Survived'].value_counts()

# %%
train_data['Survived'].value_counts().keys()

# %%
plt.figure(figsize=(5,5))
plt.bar(list(train_data['Survived'].value_counts().keys()),list(train_data['Survived'].value_counts()),color=['r','g'])
plt.show()

# %%
train_data['Pclass'].value_counts()

# %%
plt.figure(figsize=(5,5))
plt.bar(list(train_data['Pclass'].value_counts().keys()),list(train_data['Pclass'].value_counts()),color=["blue","green","Orange"])
plt.show()

# %%
train_data['Sex'].value_counts()

# %%
plt.figure(figsize=(5,5))
plt.bar(list(train_data['Sex'].value_counts().keys()),list(train_data['Sex'].value_counts()),color="purple")
plt.show()

# %%
plt.figure(figsize=(5,7))
plt.hist(train_data['Age'])
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.show()

# %%
(train_data['Survived'].isnull())

# %%
sum(train_data['Survived'].isnull())

# %%
train_data['Age'].isnull()

# %%
sum(train_data['Age'].isnull())

# %%
train_data=train_data.dropna()

# %%
sum(train_data['Survived'].isnull())

# %%
sum(train_data['Age'].isnull())

# %%
x_train=train_data[['Age']]
y_train=train_data[['Survived']]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)

# %%
sum(test_data['Age'].isnull())

# %%
test_data=test_data.dropna()

# %%
sum(test_data['Age'].isnull())

# %%
x_test=test_data[['Age']]

# %%
y_pred=dtc.predict(x_test)

# %%
y_pred
